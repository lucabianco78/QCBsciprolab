# %% [markdown]
# ### NOTE FOR LUCA
#
# **Remember to set/remove metadata as:**
# {
#   "nbsphinx": "hidden"
# }
#
# to enable/disable solutions view

# %% [markdown]
# # Practical 17
#
# In this practical we will keep working with data structures. In particular, we will see a special data structure called *tree*.
#
# ## Slides
#
# The slides of the introduction can be found here: [Intro](docs/Practical17.pdf)
#
# ## Trees
#
# Trees are data structures composed of two elements *nodes* and *edges*. Nodes represent *things* and edges represent *relationships* among **two** nodes.
#
# One node called the **root** is the top level of the tree and is connected to one or more other nodes. If the root is connected to another node by means of one edge, then it is said to be the **parent** of the node (and that node is the **child** of the root). Any node can be **parent** of one or more other nodes, the only important thing is that **all nodes have only one parent**. The **root is the only exception as it does not have any parent**. Some nodes do not have children and they are called **leaves**.
#
# An example of graph:
#
#
# ![](img/pract17/tree.png)
#
# As seen in the lecture, graphs can be defined recursively in the following way: *a tree is a root and zero or more subtrees,each of which is also a tree. The root of each subtree is connected to the root of the parent tree by an edge.*
#
# Graphically:
#
# ![](img/pract17/recursiveTree.png)
#
#
# Some properties of nodes and trees are:
#
# 1. The depth of a node N: the length of the path connecting the root to N counted as number of edges in the path.
#
# 2. The level (n) of a tree: set of nodes at the same depth (n).
#
# 3. Height : is the maximum depth of all leaves.
#
# 4. Width : the maximum number of nodes in each level.
#
# The following tree:
#
# ![](img/pract17/exampleTree.png)
#
# has four levels (0,1,2,3), height equal to 3 and width equal to 4.
#
#
# ## ADT: Binary Tree
#
# **Binary trees** are **trees** where each node has at most two children: the **right child** and the **left child**.
#
# ![](img/pract17/binaryPointers.png)
#
# The specifications of the binary tree ADT (from the lecture):
#
# ![](img/pract17/binarytreeADT.png)
#
# When implementing a tree we can define a node object and then a tree object that stores nodes, but we will use the more compact way which is to use the recursive definition of a tree.
#
# **Note:** if we want to keep attributes as private, we need to add another method to the previously seen methods: **myTree.setParent(tree)** that sets the parent of a tree **myTree** to **tree**.
#
# **Example:** Let's implement a binary tree using the recursive definition: a binary tree is a root --with a value --  connected to two subtrees, respectively the right and left subtree.

# %%
# %reset -f 

"""This could go to BinaryTree.py"""

class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self) 
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None


    
def printTree(root):
    cur = root
    #each element is a node and a depth
    #depth is used to format prints (with tabs)
    nodes = [(cur,0)]
    tabs = ""
    lev = 0
    while len(nodes) >0:
        cur, lev = nodes.pop(-1)
        #print("{}{}".format("\t"*lev, cur.getValue()))
        if cur.getRight() != None:
            print ("{}{} (r)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getRight().getValue()))
            nodes.append((cur.getRight(), lev+1))
        if cur.getLeft() != None:
            print ("{}{} (l)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getLeft().getValue()))
            nodes.append((cur.getLeft(), lev+1))
        
if __name__ == "__main__":
    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    printTree(BT)
    print("\nDelete right branch of 2")
    bt2.deleteRight()
    printTree(BT)
    
    print("\nInsert left branch of 5")
    newN = BinaryTree("child of 5")
    bt5.insertLeft(newN)
    printTree(BT)
# Out:
# Root (r)-> 2
# Root (l)-> 1
# 	1 (r)-> 5b
# 	1 (l)-> 5a
# 		5b (r)-> 5c
# 	2 (r)-> 6
# 	2 (l)-> 3
# 		3 (r)-> 5
# 		3 (l)-> 4
#
# Delete right branch of 2
# Root (r)-> 2
# Root (l)-> 1
# 	1 (r)-> 5b
# 	1 (l)-> 5a
# 		5b (r)-> 5c
# 	2 (l)-> 3
# 		3 (r)-> 5
# 		3 (l)-> 4
#
# Insert left branch of 5
# Root (r)-> 2
# Root (l)-> 1
# 	1 (r)-> 5b
# 	1 (l)-> 5a
# 		5b (r)-> 5c
# 	2 (l)-> 3
# 		3 (r)-> 5
# 		3 (l)-> 4
# 			5 (l)-> child of 5

# %% [markdown]
# Note that in the code above, deletion of right or left subtree means to just set the pointer to null. This destroys the whole subtree (more clever things can be done in some cases, especially with generic trees).
#
# Now we can see how to perform some visits of the trees, that is going through the nodes following the connections. In particular, there are two different types of visits: **depth first search** and **breadth first search**.
#
# ### Binary Tree visits: DFS
#
# Given a tree T, depth first search (DFS) visits all the subtrees of T going as deep as it can before going back and down another branch until all the tree is visited.
#
# DFS requires a stack and can be implemented recursively. What we do with the root during the visit defines 3 different types of visits:
#
# 1. the root is visited before the visiting the subtree : pre-order;
#
# 2. the root is visited after the left subtree but before the right subtree : in-order;
#
# 3. the root is visited after the left and right subtrees : post-order
#
#
# **Example:** Let's implement the three versions of the DFS and apply them to binary tree seen above.

# %%
class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self) 
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None
   
    def preOrderDFS(self):
        if self != None:
            r = self.getRight()
            l = self.getLeft()
            print(self.getValue())
            if l != None:
                l.preOrderDFS()
            if r != None:
                r.preOrderDFS()
    
    def inOrderDFS(self):
        if self != None:
            r = self.getRight()
            l = self.getLeft()
            if l != None:
                l.inOrderDFS()
            print(self.getValue())
            
            if r != None:
                r.inOrderDFS()
            
    def postOrderDFS(self):
        if self != None:
            r = self.getRight()
            l = self.getLeft()
            if l != None:
                l.postOrderDFS()
            if r != None:
                r.postOrderDFS()
            
            print(self.getValue())
    
def printTree(root):
    cur = root
    #each element is a node and a depth
    #depth is used to format prints (with tabs)
    nodes = [(cur,0)]
    tabs = ""
    lev = 0
    while len(nodes) >0:
        cur, lev = nodes.pop(-1)
        #print("{}{}".format("\t"*lev, cur.getValue()))
        if cur.getRight() != None:
            print ("{}{} (r)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getRight().getValue()))
            nodes.append((cur.getRight(), lev+1))
        if cur.getLeft() != None:
            print ("{}{} (l)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getLeft().getValue()))
            nodes.append((cur.getLeft(), lev+1))
        
if __name__ == "__main__":
    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    
    printTree(BT)
    print("Pre-order DFS:")
    BT.preOrderDFS()
    print("\nIn-order DFS:")
    BT.inOrderDFS()
    print("\nPost-order DFS:")
    BT.postOrderDFS()
# Out:
# Root (r)-> 2
#      (l)-> 1
# 	1 (r)-> 5b
# 	  (l)-> 5a
# 		5b (r)-> 5c
# 	2 (r)-> 6
# 	  (l)-> 3
# 		3 (r)-> 5
# 		  (l)-> 4
# Pre-order DFS:
# Root
# 1
# 5a
# 5b
# 5c
# 2
# 3
# 4
# 5
# 6
#
# In-order DFS:
# 5a
# 1
# 5b
# 5c
# Root
# 4
# 3
# 5
# 2
# 6
#
# Post-order DFS:
# 5a
# 5c
# 5b
# 1
# 4
# 5
# 3
# 6
# 2
# Root

# %% [markdown]
# Compare the results above with the graph:
#
# ![](img/pract17/bintree_2.png)

# %%
"CODE NOT SHOWN"

#Drawing a graph in pygraphviz
import pygraphviz as pgv

G=pgv.AGraph(directed=True)

#Attributes can be added when adding nodes or edge
G.add_node("Root", color='red')

G.add_node("1", color='blue')
G.add_node("2", color='blue')
G.add_node("3", color='blue')
G.add_node("4", color='black')
G.add_node("5", color='black')
G.add_node("5a", color='black')
G.add_node("5b", color='blue')
G.add_node("5c", color='black')
G.add_edge("Root" ,"2", color='blue')
G.add_edge("Root", "1", color='blue')
G.add_edge("2" ,"3", color='blue')
G.add_edge("2" ,"6", color='blue')
G.add_edge("3" ,"4", color='blue')
G.add_edge("3" ,"5", color='blue')
G.add_edge("1" ,"5a", color='blue')
G.add_edge("1" ,"5b", color='blue')
G.add_edge("5b" ,"5c", color='blue')
# write to a dot file
#G.write('test.dot')

#create a png file
G.layout(prog='dot') # use dot
G.draw('img/pract17/bintree_2.png')

# %%
"CODE NOT SHOWN"

#Drawing a graph in pygraphviz
import pygraphviz as pgv

G=pgv.AGraph(directed=True)

#Attributes can be added when adding nodes or edge
G.add_node("Root", color='red')

G.add_node("1", color='blue')
G.add_node("2", color='blue')
G.add_node("3", color='blue')
G.add_node("4", color='blue')
G.add_node("5", color='black')
G.add_node("5a", color='black')
G.add_node("5b", color='blue')
G.add_node("5c", color='black')
G.add_node("7", color='black')
G.add_node("8", color='black')
G.add_edge("Root" ,"2", color='blue')
G.add_edge("Root", "1", color='blue')
G.add_edge("2" ,"3", color='blue')
G.add_edge("2" ,"6", color='blue')
G.add_edge("3" ,"4", color='blue')
G.add_edge("3" ,"5", color='blue')
G.add_edge("1" ,"5a", color='blue')
G.add_edge("1" ,"5b", color='blue')
G.add_edge("5b" ,"5c", color='blue')
G.add_edge("4" ,"7", color='blue')
G.add_edge("4" ,"8", color='blue')

# write to a dot file
#G.write('test.dot')

#create a png file
G.layout(prog='dot') # use dot
G.draw('img/pract17/bintree_2bis.png')

# %%
"CODE NOT SHOWN"

#Drawing a graph in pygraphviz
import pygraphviz as pgv

G=pgv.AGraph(directed=True)

#Attributes can be added when adding nodes or edge
G.add_node("Root", color='red')

G.add_node("1", color='blue')
G.add_node("2", color='blue')
G.add_node("3", color='blue')
G.add_node("4", color='blue')
G.add_node("5", color='black')
G.add_node("6", color='blue')
G.add_node("5a", color='black')
G.add_node("5b", color='blue')
G.add_node("5c", color='black')
G.add_node("7", color='black')
G.add_node("8", color='black')
G.add_node("9", color='black')
G.add_node("10", color='black')
G.add_edge("Root" ,"2", color='blue')
G.add_edge("Root", "1", color='blue')
G.add_edge("2" ,"3", color='blue')
G.add_edge("2" ,"6", color='blue')
G.add_edge("3" ,"4", color='blue')
G.add_edge("3" ,"5", color='blue')
G.add_edge("1" ,"5a", color='blue')
G.add_edge("1" ,"5b", color='blue')
G.add_edge("5b" ,"5c", color='blue')
G.add_edge("4" ,"7", color='blue')
G.add_edge("4" ,"8", color='blue')
G.add_edge("6" ,"9", color='blue')
G.add_edge("6" ,"10", color='blue')

# write to a dot file
#G.write('test.dot')

#create a png file
G.layout(prog='dot') # use dot
G.draw('img/pract17/bintree_2tris.png')

# %% [markdown]
# ### Binary Tree visits: BFS
#
# **Breadth first search** visits all the higher levels of a tree before going down. Basically, this search goes as wide as it can before going deep.
#
# This visit makes use of a queue: for each tree, it adds the left and right subtrees to the queue  and recursively visits them in the order they have been pushed into the queue.
#
# As said, implementations of BFS make use of a FIFO queue, in python we can use the efficient ```deque``` data structure that is implemented in the ```collections``` module (remember to import it first with ```from collections import deque``` and use ```deque.append``` to add at the end and ```deque.popleft``` to remove from the beginning).
#
# **Example:** Let's implement a BFS method and apply it to binary tree seen above.

# %%
from collections import deque

class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self) 
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None
   
    def BFS(self):
        if self != None:
            level = deque()
            level.append(self)
            
            
            while len(level) > 0:
                #print(len(level))
                cur = level.popleft()
                print(cur.getValue())
                r = cur.getRight()
                l = cur.getLeft()
                if l != None:
                    #print("from {} Appending: {}".format(cur.getValue(), 
                    #                                      l.getValue()))
                    level.append(l)
                if r != None:
                    level.append(r)
                    #print("from {} Appending: {}".format(cur.getValue(), 
                    #                                     r.getValue()))
    
    
    
def printTree(root):
    cur = root
    #each element is a node and a depth
    #depth is used to format prints (with tabs)
    nodes = [(cur,0)]
    tabs = ""
    lev = 0
    while len(nodes) >0:
        cur, lev = nodes.pop(-1)
        #print("{}{}".format("\t"*lev, cur.getValue()))
        if cur.getRight() != None:
            print ("{}{} (r)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getRight().getValue()))
            nodes.append((cur.getRight(), lev+1))
        if cur.getLeft() != None:
            print ("{}{} (l)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getLeft().getValue()))
            nodes.append((cur.getLeft(), lev+1))
        
if __name__ == "__main__":
    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    
    printTree(BT)
    print("BFS:")
    BT.BFS()
# Out:
# Root (r)-> 2
# Root (l)-> 1
# 	1 (r)-> 5b
# 	1 (l)-> 5a
# 		5b (r)-> 5c
# 	2 (r)-> 6
# 	2 (l)-> 3
# 		3 (r)-> 5
# 		3 (l)-> 4
# BFS:
# Root
# 1
# 2
# 5a
# 5b
# 3
# 6
# 5c
# 4
# 5

# %% [markdown]
# Compare the results above with the graph:
#
# ![](img/pract17/bintree_2.png)

# %%
"""CODE NOT SHOWN!"""


#Drawing a graph in pygraphviz
import pygraphviz as pgv

G=pgv.AGraph(directed=True)

#Attributes can be added when adding nodes or edge
G.add_node("ROOT", color='red')
for i in range(0,3):
    G.add_node("Child_%i" % i, color='blue')
    G.add_node("Grandchild_%ia" % i, color='blue')
    G.add_node("Grandchild_%ib" % i, color='blue')
    G.add_node("Leaf_%i" % i, color='black')

    G.add_edge("ROOT", "Child_%i" % i, color='blue')
    G.add_edge("Child_%i" % i, "Grandchild_%ia" % i, color='blue')
    G.add_edge("Child_%i" % i, "Grandchild_%ib" % i, color='blue')
    if i % 2 == 0:
        G.add_edge("Grandchild_%ia" % i, "Leaf_%i" % i, color='black')        
        G.add_node("Leaf_%ia" %i, color = 'black')
        G.add_node("Leaf_%ib" %i, color = 'black')
        G.add_edge("Grandchild_%ib" % i, "Leaf_%ia" % i, color='black')
        G.add_edge("Grandchild_%ib" % i, "Leaf_%ib" % i, color='black')
    else:
        G.add_edge("Grandchild_%ib" % i, "Leaf_%i" % i, color='black')
        G.add_node("Leaf_%ia" %i, color = 'black')
        G.add_node("Leaf_%ib" %i, color = 'black')
        G.add_edge("Grandchild_%ia" % i, "Leaf_%ia" % i, color='black')
        G.add_edge("Grandchild_%ia" % i, "Leaf_%ib" % i, color='black')

# write to a dot file
#G.write('test.dot')

#create a png file
G.layout(prog='dot') # use dot
G.draw('img/pract17/tree.png')

# %% [markdown]
# ### ADT: Generic Tree
#
# Generic Trees are like binary trees, but **each node can have more than 2 children**. One possible implementation is that each node (that is a subtree in itself) has a **value**, a link to its **parent** and a **list of children**.
#
# Another implementation is that each node has a **value**, a link to its **parent**, a link to its **next sibling** and a link to its **first child**:
#
# ![](img/pract17/genericTreePointers.png)
#
# We will be using this latter implementation of the tree.
#
# The **Generic Tree ADT** seen at lecture follows:
#
# ![](img/pract17/genericTreeADT.png)
#
# Given the following generic tree:
#
# ![](img/pract17/gentree_1.png)
#
#
# **Example:** Implement the a GenericTree class representing the ADT seen above and create the tree in the picture above.

# %%
# %reset -f 

class GenericTree:
    #This actually allows for forests
    #unless we force the root to have no siblings.
    def __init__(self, value):
        self.__data = value
        self.__parent = None
        self.__child = None
        self.__sibling = None
        
    def getValue(self):
        return self.__data
    
    def setValue(self,newvalue):
        self.__data = newvalue
    
    def getParent(self):
        return self.__parent
    
    #not specified in ADT but needed
    #to add nodes
    def setParent(self, parent):
        self.__parent = parent
    
    def getLeftmostChild(self):
        return self.__child
    
    def getSibling(self):
        return self.__sibling
    #not specified in ADT but needed
    #to add nodes
    def setSibling(self,sib):
        self.__sibling = sib
        
    def insertSibling(self,sib):
        if type(sib) != GenericTree:
            raise TypeError("parameter sib is not a GenericTree")
        else:
            nextS = None
            if self.__sibling != None:
                nextS = self.__sibling  
            self.__sibling = sib
            sib.setParent(self.getParent())
            sib.setSibling(nextS)
        
            
    def insertChild(self,child):
        if type(child) != GenericTree:
            raise TypeError("parameter child is not a GenericTree")
        else:
            nextC = None
            print("from {} adding child --> {}".format(self.getValue(),
                                                       child.getValue()))
            if self.__child != None:
                nextC = self.__child
            child.setParent(self)
            child.setSibling(nextC)
            self.__child = child
           
    def deleteChild(self):
        if self.__child != None:
            #moves along the sibling structure of child
            self.__child = self.__child.getSibling()
        
    def deleteSibling(self):
        if self.__sibling != None:
            #moves along the sibling structure of the sibling
            self.__sibling = self.__sibling.getSibling()
            
if __name__ == "__main__":
    g = GenericTree("Root")
    g1 = GenericTree("First")
    g2 = GenericTree("Second")
    g3 = GenericTree("Third")
    g4 = GenericTree("Fourth")
    g5 = GenericTree("Fifth")
    g6 = GenericTree("Sixth")
    g7 = GenericTree("Seventh")
    g8 = GenericTree("Eighth")
    g9 = GenericTree("Ninth")
    g10 = GenericTree("Tenth")
    g11 = GenericTree("Eleventh")
    
    #root
    g.insertChild(g4)
    g.insertChild(g3)
    g.insertChild(g2)
    g.insertChild(g1)
    #second
    g2.insertChild(g6)
    g2.insertChild(g5)
    #fourth
    g4.insertChild(g7)
    g7.insertSibling(g11)
    #sixth
    g6.insertChild(g10)
    g6.insertChild(g9)
    g6.insertChild(g8)
    
    
    #let's print some stuff
    nodes = [g,g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11]
    for n in nodes:
        print("Node {}:".format(n.getValue()))
        par = n.getParent()
        if par != None:
            par = par.getValue()
        print("\t has parent: {}".format(par))
        c = n.getLeftmostChild()
        children = []
        if c != None:
            children.append(c.getValue())
            nc = c.getSibling()
            while nc != None:
                children.append(nc.getValue())
                nc = nc.getSibling()
        print("\t has children: {}".format(",".join(children)))
        s = n.getSibling()
        sibs = []
        if s != None:
            sibs.append(s.getValue())
            ns = s.getSibling()
            while ns != None:
                sibs.append(ns.getValue())
                ns = ns.getSibling()
        print("\t has next siblings: {}".format(",".join(sibs)))
# Out:
# from Root adding child --> Fourth
# from Root adding child --> Third
# from Root adding child --> Second
# from Root adding child --> First
# from Second adding child --> Sixth
# from Second adding child --> Fifth
# from Fourth adding child --> Seventh
# from Sixth adding child --> Tenth
# from Sixth adding child --> Ninth
# from Sixth adding child --> Eighth
# Node Root:
# 	 has parent: None
# 	 has children: First,Second,Third,Fourth
# 	 has next siblings:
# Node First:
# 	 has parent: Root
# 	 has children:
# 	 has next siblings: Second,Third,Fourth
# Node Second:
# 	 has parent: Root
# 	 has children: Fifth,Sixth
# 	 has next siblings: Third,Fourth
# Node Third:
# 	 has parent: Root
# 	 has children:
# 	 has next siblings: Fourth
# Node Fourth:
# 	 has parent: Root
# 	 has children: Seventh,Eleventh
# 	 has next siblings:
# Node Fifth:
# 	 has parent: Second
# 	 has children:
# 	 has next siblings: Sixth
# Node Sixth:
# 	 has parent: Second
# 	 has children: Eighth,Ninth,Tenth
# 	 has next siblings:
# Node Seventh:
# 	 has parent: Fourth
# 	 has children:
# 	 has next siblings: Eleventh
# Node Eighth:
# 	 has parent: Sixth
# 	 has children:
# 	 has next siblings: Ninth,Tenth
# Node Ninth:
# 	 has parent: Sixth
# 	 has children:
# 	 has next siblings: Tenth
# Node Tenth:
# 	 has parent: Sixth
# 	 has children:
# 	 has next siblings:
# Node Eleventh:
# 	 has parent: Fourth
# 	 has children:
# 	 has next siblings:

# %% [markdown]
# Note that the siblings list is actually unidirectional therefore "Second" does not any way to know that it is on the same level of "First".

# %%
"CODE NOT SHOWN"

#Drawing a graph in pygraphviz
import pygraphviz as pgv

G=pgv.AGraph(directed=True)

#Attributes can be added when adding nodes or edge
G.add_node("Root", color='red')

G.add_node("First", color='black')
G.add_node("Second", color='blue')
G.add_node("Third", color='blue')
G.add_node("Fourth", color='blue')
G.add_node("Fifth", color='black')
G.add_node("Sixth", color='blue')
G.add_node("Seventh", color='black')
G.add_node("Eighth", color='black')
G.add_node("Ninth", color='black')
G.add_node("Tenth", color='black')
G.add_node("Eleventh", color='black')

G.add_edge("Root" ,"First", color='blue')
G.add_edge("Root", "Second", color='blue')
G.add_edge("Root" ,"Third", color='blue')
G.add_edge("Root" ,"Fourth", color='blue')
G.add_edge("Second" ,"Fifth", color='blue')
G.add_edge("Second" ,"Sixth", color='blue')
G.add_edge("Fourth" ,"Seventh", color='blue')
G.add_edge("Sixth" ,"Eighth", color='blue')
G.add_edge("Sixth" ,"Ninth", color='blue')
G.add_edge("Sixth" ,"Tenth", color='blue')
G.add_edge("Fourth" ,"Eleventh", color='blue')
# write to a dot file
#G.write('test.dot')

#create a png file
G.layout(prog='dot') # use dot
G.draw('img/pract17/gentree_1.png')

# %% [markdown]
# ## Exercises

# %% [markdown]
# 1. Modify the BinaryTree class adding a ```depth``` parameter counting, for each subtree, its depth (i.e. distance from the root of the tree). Note that you have to update properly the depth when inserting a new node. Add a ```getDepth``` and ```setDepth``` method too.
#
# If needed, you can download the code of the  original BinaryTree class here: [BinaryTree.py](file_samples/BinaryTree.py).
#
# a. Test the code printing the depth of the binary graph:
#
# ![](img/pract17/bintree_2bis.png)
#
# that can be created with:
#
# ```
# BT = BinaryTree("Root")
# bt1 = BinaryTree(1)
# bt2 = BinaryTree(2)
# bt3 = BinaryTree(3)
# bt4 = BinaryTree(4)
# bt5 = BinaryTree(5)
# bt6 = BinaryTree(6)
# bt5a = BinaryTree("5a")
# bt5b = BinaryTree("5b")
# bt5c = BinaryTree("5c")
# bt7 = BinaryTree(7)
# bt8 = BinaryTree(8)
# BT.insertLeft(bt1)
# BT.insertRight(bt2)
# bt2.insertLeft(bt3)
# bt3.insertLeft(bt4)
# bt3.insertRight(bt5)
# bt2.insertRight(bt6)
# bt1.insertRight(bt5b)
# bt1.insertLeft(bt5a)
# bt5b.insertRight(bt5c)
# bt4.insertRight(bt7)
# bt4.insertLeft(bt8)
# ```
# <div class="tggle" onclick="toggleVisibility('ex1');">Show/Hide Solution</div>
# <div id="ex1" style="display:none;">

# %%
# %reset -f


class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        #new param
        self.__depth = 0
    
    # new method
    def getDepth(self):
        return self.__depth
    
    # new method
    def setDepth(self, newdepth):
        self.__depth = newdepth
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self)
            #line modified
            tree.setDepth(self.getDepth() + 1)
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            #line modified
            tree.setDepth(self.getDepth() + 1)
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None


    
def printTree(root):
    cur = root
    #each element is a node and a depth
    #depth is used to format prints (with tabs)
    nodes = [(cur,0)]
    tabs = ""
    lev = 0
    while len(nodes) >0:
        cur, lev = nodes.pop(-1)
        #print("{}{}".format("\t"*lev, cur.getValue()))
        if cur.getRight() != None:
            print ("{}{} (r)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getRight().getValue()))
            nodes.append((cur.getRight(), lev+1))
        if cur.getLeft() != None:
            print ("{}{} (l)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getLeft().getValue()))
            nodes.append((cur.getLeft(), lev+1))
        
if __name__ == "__main__":
    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    bt7 = BinaryTree(7)
    bt8 = BinaryTree(8)
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    bt4.insertRight(bt7)
    bt4.insertLeft(bt8)

    nodeList = [BT,bt1,bt2,bt3,bt4, bt5, bt5a, bt5b, 
                bt5c, bt6, bt7, bt8]
    for node in nodeList:
        if node != None:
            print("Node {} has depth: {}".format(node.getValue(), 
                                                 node.getDepth()))
# Out:
# Node Root has depth: 0
# Node 1 has depth: 1
# Node 2 has depth: 1
# Node 3 has depth: 2
# Node 4 has depth: 3
# Node 5 has depth: 3
# Node 5a has depth: 2
# Node 5b has depth: 2
# Node 5c has depth: 3
# Node 6 has depth: 2
# Node 7 has depth: 4
# Node 8 has depth: 4

# %% [markdown]
# </div>

# %% [markdown]
# 2. The width of a binary tree T is the largest number of nodes that belong to the same level. The minimal height of a binary tree T is the minimal distance between the root and its closest leaf in its subtree. This distance is counted in number of nodes.
#
# Given the BinaryTree defined above:
#
# a. Write a function ```getWidth(T)``` that given a tree T, returns the width of T. Hint: get all nodes at each level and count them.
#
# b. Write a function ```getMinHeight(T)``` that given a tree T, returns the minimal height of T. Hint: stop at first level with a leaf (similar to previous function).
#
# c. Write a function ```nodesAtLevel(T,k)``` that given a binary tree T and an integer k, returns the number of nodes at level k.
#
# Test the functions with the following binary graph:
#
# ![](img/pract17/bintree_2tris.png)
#
# that can be created with:
#
# ```
# BT = BinaryTree("Root")
# bt1 = BinaryTree(1)
# bt2 = BinaryTree(2)
# bt3 = BinaryTree(3)
# bt4 = BinaryTree(4)
# bt5 = BinaryTree(5)
# bt6 = BinaryTree(6)
# bt5a = BinaryTree("5a")
# bt5b = BinaryTree("5b")
# bt5c = BinaryTree("5c")
# bt7 = BinaryTree(7)
# bt8 = BinaryTree(8)
# bt9 = BinaryTree(9)
# bt10 = BinaryTree(10)
# BT.insertLeft(bt1)
# BT.insertRight(bt2)
# bt2.insertLeft(bt3)
# bt3.insertLeft(bt4)
# bt3.insertRight(bt5)
# bt2.insertRight(bt6)
# bt1.insertRight(bt5b)
# bt1.insertLeft(bt5a)
# bt5b.insertRight(bt5c)
# bt4.insertRight(bt7)
# bt4.insertLeft(bt8)
# bt6.insertRight(bt10)
# bt6.insertLeft(bt9)
# ```
#
# <div class="tggle" onclick="toggleVisibility('ex2');">Show/Hide Solution</div>
# <div id="ex2" style="display:none;">

# %%
# %reset -f 

class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        #new param
        self.__depth = 0
    
    # new method
    def getDepth(self):
        return self.__depth
    
    # new method
    def setDepth(self, newdepth):
        self.__depth = newdepth
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self)
            #line modified
            tree.setDepth(self.getDepth() + 1)
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            #line modified
            tree.setDepth(self.getDepth() + 1)
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None
            
            
        
def getWidth(tree):
    """gets the width of the tree"""
    if tree == None:
        return 0
    
    level = [tree]
    res = 1
    while len(level) > 0:
        tmp = []
        for t in level:
            r = t.getRight()
            l = t.getLeft()
            if r != None:
                tmp.append(r)
            if l != None:
                tmp.append(l)
        res = max(res,len(tmp))
        level = tmp
        
    return res

def getMinHeight(tree):
    """gets the minimum height of the tree in nodes"""
    if tree == None:
        return 0
    
    level = [tree]
    res = 1
    while len(level) > 0:
        tmp = []
        for t in level:
            r = t.getRight()
            l = t.getLeft()
            if r == None and l == None:
                return res
            else:
                if r != None:
                    tmp.append(r)
                if l != None:
                    tmp.append(l)
        level = tmp
        res += 1
    return res

def nodesAtLevel(tree,k):
    """returns the number of nodes at level k"""
    if tree == None:
        return 0
    
    level = [tree]
    cnt = 0
    while cnt != k and len(level) > 0:
        tmp = []
        for t in level:
            r = t.getRight()
            l = t.getLeft()
            if l != None:
                tmp.append(l)
            if r != None:
                tmp.append(r)
                
        level = tmp
        cnt += 1
    if len(level) == 0:
        return None
    else:
        vals = [x.getValue() for x in level if x != None]
        return vals
     
    
if __name__ == "__main__":

    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    bt7 = BinaryTree(7)
    bt8 = BinaryTree(8)
    bt9 = BinaryTree(9)
    bt10 = BinaryTree(10)
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    bt4.insertRight(bt7)
    bt4.insertLeft(bt8)
    bt6.insertRight(bt10)
    bt6.insertLeft(bt9)
    
    print("The width of BT is {}".format(getWidth(BT)))
    print("The minimum height of BT is {}".format(getMinHeight(BT)))
    for i in range(0,6):
        print("Nodes at level {}: {}".format(i,nodesAtLevel(BT,i)))
    print("The minimum height of BT is {}".format(getMinHeight(BT)))
    bt1.deleteLeft()
    print("Deleting 5ca")
    print("The minimum height of BT is {}".format(getMinHeight(BT)))
    bt5d = BinaryTree("5d")
    bt5c.insertLeft(bt5d)
    print("Adding 5d as left child of 5c")
    print("The minimum height of BT is {}".format(getMinHeight(BT)))
# Out:
# The width of BT is 5
# The minimum height of BT is 3
# Nodes at level 0: ['Root']
# Nodes at level 1: [1, 2]
# Nodes at level 2: ['5a', '5b', 3, 6]
# Nodes at level 3: ['5c', 4, 5, 9, 10]
# Nodes at level 4: [8, 7]
# Nodes at level 5: None
# The minimum height of BT is 3
# Deleting 5ca
# The minimum height of BT is 4
# Adding 5d as left child of 5c
# The minimum height of BT is 4

# %% [markdown]
# </div>

# %% [markdown]
# 3. Given the BinaryTree used so far, implement a ```getCommonAncestor(n1,n2)``` method that gets the common ancestor between the two nodes n1 and n2.
#
# For example, considering the graph above:
#
# ```
# getCommonAncestor(7,5) = 3
# getCommonAncestor(7,10) = 2
# getCommonAncestor(8,5b) = Root
# getCommonAncestor(8,3) = 3
# ```
# <div class="tggle" onclick="toggleVisibility('ex3');">Show/Hide Solution</div>
# <div id="ex3" style="display:none;">

# %%
# %reset -f 

class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        #new param
        self.__depth = 0
    
    # new method
    def getDepth(self):
        return self.__depth
    
    # new method
    def setDepth(self, newdepth):
        self.__depth = newdepth
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self)
            #line modified
            tree.setDepth(self.getDepth() + 1)
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            #line modified
            tree.setDepth(self.getDepth() + 1)
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None
            
            
        
def getCommonAncestor( node1, node2):
    if node1 == node2:
        return node1
    
    if node1 == None or node2 == None:
        return None
    n1anc = set()
    n1anc.add(node1)
    
    anc = node1.getParent()
    while anc != None:
        n1anc.add(anc)
        anc = anc.getParent()
    
    anc = node2
    while anc != None:
        if anc in n1anc:
            return anc
        else:
            anc = anc.getParent()
    

    
if __name__ == "__main__":
    

    BT = BinaryTree("Root")
    bt1 = BinaryTree(1)
    bt2 = BinaryTree(2)
    bt3 = BinaryTree(3)
    bt4 = BinaryTree(4)
    bt5 = BinaryTree(5)
    bt6 = BinaryTree(6)
    bt5a = BinaryTree("5a")
    bt5b = BinaryTree("5b")
    bt5c = BinaryTree("5c")
    bt7 = BinaryTree(7)
    bt8 = BinaryTree(8)
    bt9 = BinaryTree(9)
    bt10 = BinaryTree(10)
    BT.insertLeft(bt1)
    BT.insertRight(bt2)
    bt2.insertLeft(bt3)
    bt3.insertLeft(bt4)
    bt3.insertRight(bt5)
    bt2.insertRight(bt6)
    bt1.insertRight(bt5b)
    bt1.insertLeft(bt5a)
    bt5b.insertRight(bt5c)
    bt4.insertRight(bt7)
    bt4.insertLeft(bt8)
    bt6.insertRight(bt10)
    bt6.insertLeft(bt9)
    
    ca = getCommonAncestor(bt7,bt5)
    if ca != None:
        ca = ca.getValue()
    print("The CA between {} and {} is: {}".format(bt7.getValue(),
                                                  bt5.getValue(),
                                                  ca))
    ca = getCommonAncestor(bt7,bt10)
    if ca != None:
        ca = ca.getValue()
    print("The CA between {} and {} is: {}".format(bt7.getValue(),
                                                  bt10.getValue(),
                                                  ca))
    ca = getCommonAncestor(bt7,bt8)
    if ca != None:
        ca = ca.getValue()
    print("The CA between {} and {} is: {}".format(bt7.getValue(),
                                                  bt8.getValue(),
                                                  ca))
    
    ca = getCommonAncestor(bt5b,bt8)
    if ca != None:
        ca = ca.getValue()
    print("The CA between {} and {} is: {}".format(bt5b.getValue(),
                                                  bt8.getValue(),
                                                  ca))
    
    ca = getCommonAncestor(bt3,bt8)
    if ca != None:
        ca = ca.getValue()
    print("The CA between {} and {} is: {}".format(bt3.getValue(),
                                                  bt8.getValue(),
                                                  ca))
# Out:
# The CA between 7 and 5 is: 3
# The CA between 7 and 10 is: 2
# The CA between 7 and 8 is: 4
# The CA between 5b and 8 is: Root
# The CA between 3 and 8 is: 3

# %% [markdown]
# </div>

# %% [markdown]
# 4. A Binary Search Tree, is binary tree with the following properties:
#
# a. The left subtree of a node contains only nodes with values lower than that of the node.
#
# b. The right subtree of a node contains only nodes with values greater than the node’s.
#
# c. No duplicate nodes are allowed.
#
#
# Implement:
#
# 1. a function ```BST = createBST(inList)``` that gets a list of integers (or strings) and returns a BinaryTree that is a Binary Search Tree;
#
# 2. a search function ```searchBST(BST, element)``` that gets an integer (or string) and checks if it is present in the Binary Search Tree.
#
# 3. modify the ```inOrderDFS(self)``` method to return a list of visited nodes in in-order depth first search. Test the method by printing the first 100 elements to show that they are actually sorted (this is a sorting algorithm effectively!);
#
# Test the code with the following ```intList```:
#
# ```
# import random
# intList = []
# for i in range(1000):
#     inList.append(random.randint(0,10000))
# ```
#
# NOTE: This solution shows you how to plot a graph (makes use of pygraphviz, which is an off-topic for this course). You can see a sample output of the plot here [BST_test](img/pract17/BST_test.png)
#
#
# <div class="tggle" onclick="toggleVisibility('ex4');">Show/Hide Solution</div>
# <div id="ex4" style="display:none;">

# %%
# %reset -f

class BinaryTree:
    def __init__(self, value):
        self.__data = value
        self.__right = None
        self.__left = None
        self.__parent = None
        #new param
        self.__depth = 0
    
    # new method
    def getDepth(self):
        return self.__depth
    
    # new method
    def setDepth(self, newdepth):
        self.__depth = newdepth
        
    def getValue(self):
        return self.__data
    
    def setValue(self, newval):
        self.__data = newval
    
    def getParent(self):
        return self.__parent
    
    #needed because we are using private attributes
    def setParent(self, tree):
        self.__parent = tree
    
    def getRight(self):
        return self.__right
    
    def getLeft(self):
        return self.__left
    
    def insertRight(self, tree):
        if self.__right == None:
            self.__right = tree
            tree.setParent(self)
            #line modified
            tree.setDepth(self.getDepth() + 1)
                    
    def insertLeft(self, tree):
        if self.__left == None:
            self.__left = tree
            #line modified
            tree.setDepth(self.getDepth() + 1)
            tree.setParent(self)
            
    def deleteRight(self):
        self.__right = None
        
    def deleteLeft(self):
        self.__left = None
        
    def inOrderDFS(self):
        ret = []
        if self != None:
            r = self.getRight()
            l = self.getLeft()
            if l != None:
                ret.extend(l.inOrderDFS())
            ret.append(self.getValue())
            
            if r != None:
                ret.extend(r.inOrderDFS())
        return ret

def createBST(intList):
    BST = None
    if len(inList) > 0:
        BST = BinaryTree(inList[0])
        for el in intList[1:]:
            cur_el = BST
            alreadyPresent = False
            prev_el = None
            while cur_el != None:
                prev_el = cur_el
                cv = cur_el.getValue()
                if  cv > el:
                    cur_el = cur_el.getLeft()
                elif cv < el:
                    cur_el = cur_el.getRight()
                else:
                    #cv == el (el is already present)
                    #not allowed by rule c. skip it
                    alreadyPresent = True
                    #print("El {} already present".format(el))
                    break
                
                
            if not alreadyPresent:
                node = BinaryTree(el)
                node.setParent(prev_el)
                if prev_el.getValue() > el:
                    prev_el.insertLeft(node)
                else:
                    prev_el.insertRight(node)
                
        
    return BST
    
def searchBST(BST, element):
    if BST == None or element == None:
        return False
    else:
        cur_el = BST
        while cur_el != None:
            if cur_el.getValue() == element:
                return True
            else:
                if cur_el.getValue()> element:
                    cur_el = cur_el.getLeft()
                else:
                    cur_el = cur_el.getRight()
        
        return False


def printTree(root):
    cur = root
    #each element is a node and a depth
    #depth is used to format prints (with tabs)
    nodes = [(cur,0)]
    tabs = ""
    lev = 0
    while len(nodes) >0:
        cur, lev = nodes.pop(-1)
        #print("{}{}".format("\t"*lev, cur.getValue()))
        if cur.getRight() != None:
            print ("{}{} (r)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getRight().getValue()))
            nodes.append((cur.getRight(), lev+1))
        if cur.getLeft() != None:
            print ("{}{} (l)-> {}".format("\t"*lev, 
                                          cur.getValue(), 
                                          cur.getLeft().getValue()))
            nodes.append((cur.getLeft(), lev+1))
     


def plotGraph(tree):    
    #uses pygraphviz 
    G=pgv.AGraph(directed=True)
    
    levels = [tree]
    while len(levels) > 0:
        cur_n = levels.pop()
        if cur_n != None:
            G.add_node(cur_n.getValue(), color = 'black')
            r = cur_n.getRight()
            l = cur_n.getLeft()
            if l != None:
                G.add_node(l.getValue(), color = 'black')
                G.add_edge(cur_n.getValue(), l.getValue())
                levels.append(l)
            if r != None:
                G.add_node(r.getValue(), color = 'black')
                G.add_edge(cur_n.getValue(), r.getValue())
                levels.append(r)
    G.layout(prog='dot') # use dot
    #In the following, the path of the graph. Change
    #it to your liking
    G.draw('img/pract17/BST_test.png')
       
    
if __name__ == "__main__":
    import random
    import pygraphviz as pgv
    #import time 
    inList = []
    for i in range(1000):
        inList.append(random.randint(0,10000))
        
    BST = createBST(inList)
    
    #printTree(BST)
    plotGraph(BST)
    for i in range(1000):
        v = random.randint(0,10000)
        #s_t = time.time()
        ok = searchBST(BST, v)
        #e_t = time.time()
        okL = v in inList
        #e_t2 = time.time()
        print("el {} : present? {}".format(v, ok))
        #print("Time BST:{:.6f} list:{:.6f}".format(e_t - s_t,
        #                                           e_t2 - e_t
        #                                            ))
        assert(ok == okL)
    sorted = BST.inOrderDFS()
    print("\nIn order DFS (first 100 elements):")
    print(sorted[0:100])
# Out:
# el 5516 : present? False
# el 409 : present? False
# el 849 : present? False
# el 7745 : present? False
# el 8355 : present? True
# el 6407 : present? False
# el 8303 : present? False
# el 7273 : present? False
# el 8397 : present? False
# el 6224 : present? False
# el 4644 : present? False
# el 4950 : present? True
# el 696 : present? False
# el 8936 : present? False
# el 1201 : present? True
# el 2499 : present? False
# el 7358 : present? False
# el 9400 : present? False
# el 5696 : present? False
# el 304 : present? False
# el 6001 : present? False
# el 2713 : present? False
# el 7040 : present? False
# el 748 : present? False
# el 9558 : present? False
# el 3252 : present? False
# el 3854 : present? False
# el 3083 : present? False
# el 5260 : present? False
# el 8373 : present? True
# el 4741 : present? False
# el 1929 : present? False
# el 8048 : present? False
# el 8689 : present? True
# el 7914 : present? False
# el 976 : present? False
# el 7981 : present? False
# el 1856 : present? False
# el 2955 : present? False
# el 2246 : present? False
# el 9435 : present? False
# el 7675 : present? True
# el 5508 : present? False
# el 6038 : present? False
# el 2022 : present? False
# el 862 : present? False
# el 14 : present? False
# el 7961 : present? False
# el 4659 : present? True
# el 1230 : present? False
# el 2211 : present? False
# el 8446 : present? False
# el 4024 : present? False
# el 6485 : present? False
# el 3856 : present? False
# el 1867 : present? False
# el 6603 : present? False
# el 2210 : present? False
# el 6958 : present? False
# el 3228 : present? False
# el 8616 : present? True
# el 6970 : present? False
# el 7734 : present? True
# el 8340 : present? False
# el 2702 : present? False
# el 2492 : present? False
# el 4650 : present? False
# el 5464 : present? True
# el 4566 : present? False
# el 9146 : present? False
# el 1146 : present? False
# el 2241 : present? False
# el 372 : present? False
# el 9106 : present? False
# el 6619 : present? False
# el 1004 : present? False
# el 799 : present? False
# el 4577 : present? False
# el 2615 : present? False
# el 155 : present? False
# el 5096 : present? False
# el 9317 : present? False
# el 9721 : present? False
# el 7970 : present? False
# el 2303 : present? False
# el 4506 : present? False
# el 8434 : present? False
# el 148 : present? False
# el 3260 : present? False
# el 1648 : present? False
# el 5535 : present? True
# el 8164 : present? False
# el 5440 : present? False
# el 7238 : present? False
# el 7818 : present? False
# el 7200 : present? False
# el 8987 : present? False
# el 5836 : present? False
# el 4340 : present? False
# el 394 : present? False
# el 3083 : present? False
# el 296 : present? False
# el 5161 : present? False
# el 9433 : present? False
# el 3558 : present? False
# el 4834 : present? False
# el 8840 : present? False
# el 5900 : present? False
# el 5273 : present? False
# el 6849 : present? False
# el 718 : present? False
# el 8754 : present? False
# el 2001 : present? False
# el 8593 : present? False
# el 5498 : present? False
# el 5123 : present? False
# el 3508 : present? False
# el 3909 : present? False
# el 4065 : present? False
# el 6705 : present? False
# el 5970 : present? False
# el 4582 : present? False
# el 4748 : present? False
# el 6086 : present? False
# el 7759 : present? False
# el 8638 : present? False
# el 5889 : present? False
# el 6053 : present? False
# el 2093 : present? False
# el 9064 : present? False
# el 6224 : present? False
# el 484 : present? False
# el 9787 : present? False
# el 1949 : present? False
# el 8359 : present? False
# el 9969 : present? False
# el 9705 : present? False
# el 5200 : present? False
# el 2439 : present? False
# el 5447 : present? False
# el 4922 : present? True
# el 5698 : present? False
# el 8354 : present? True
# el 640 : present? False
# el 5655 : present? False
# el 497 : present? False
# el 4108 : present? False
# el 3769 : present? False
# el 8670 : present? False
# el 1049 : present? False
# el 2800 : present? False
# el 3999 : present? True
# el 9628 : present? False
# el 135 : present? False
# el 8702 : present? False
# el 2032 : present? False
# el 8383 : present? False
# el 4833 : present? False
# el 743 : present? False
# el 8588 : present? False
# el 6761 : present? False
# el 1974 : present? True
# el 2192 : present? False
# el 3665 : present? False
# el 1378 : present? False
# el 8404 : present? False
# el 2484 : present? False
# el 9289 : present? False
# el 8631 : present? False
# el 3783 : present? False
# el 5359 : present? False
# el 777 : present? False
# el 8181 : present? False
# el 683 : present? True
# el 8146 : present? False
# el 6646 : present? False
# el 7452 : present? False
# el 4763 : present? False
# el 7913 : present? False
# el 8974 : present? False
# el 2563 : present? False
# el 641 : present? False
# el 6682 : present? False
# el 6289 : present? False
# el 390 : present? True
# el 6049 : present? True
# el 7219 : present? False
# el 5073 : present? False
# el 26 : present? False
# el 9062 : present? False
# el 9265 : present? False
# el 6764 : present? False
# el 8690 : present? False
# el 7841 : present? True
# el 446 : present? False
# el 488 : present? False
# el 7361 : present? False
# el 8886 : present? False
# el 8010 : present? False
# el 9830 : present? False
# el 4714 : present? False
# el 698 : present? False
# el 6552 : present? False
# el 364 : present? False
# el 458 : present? False
# el 7136 : present? False
# el 1464 : present? True
# el 6802 : present? False
# el 3422 : present? True
# el 8359 : present? False
# el 3345 : present? False
# el 4156 : present? True
# el 9343 : present? False
# el 8011 : present? False
# el 20 : present? False
# el 2599 : present? False
# el 2174 : present? False
# el 6222 : present? False
# el 9047 : present? False
# el 3457 : present? False
# el 2917 : present? False
# el 8144 : present? False
# el 7685 : present? False
# el 2577 : present? False
# el 2449 : present? False
# el 1947 : present? True
# el 2091 : present? False
# el 3082 : present? False
# el 5672 : present? False
# el 2607 : present? False
# el 5920 : present? False
# el 8318 : present? False
# el 8622 : present? False
# el 6950 : present? False
# el 8546 : present? False
# el 463 : present? False
# el 7072 : present? False
# el 8385 : present? True
# el 5166 : present? False
# el 8338 : present? False
# el 6361 : present? False
# el 7032 : present? False
# el 8211 : present? False
# el 9533 : present? False
# el 5192 : present? True
# el 7074 : present? False
# el 2884 : present? False
# el 6159 : present? False
# el 9898 : present? False
# el 8762 : present? False
# el 6469 : present? False
# el 9865 : present? False
# el 9949 : present? False
# el 1239 : present? True
# el 5083 : present? False
# el 9210 : present? False
# el 8410 : present? False
# el 3784 : present? True
# el 110 : present? False
# el 4393 : present? False
# el 1654 : present? False
# el 9036 : present? False
# el 1788 : present? False
# el 6449 : present? False
# el 203 : present? False
# el 2147 : present? True
# el 4934 : present? True
# el 7064 : present? False
# el 8282 : present? False
# el 8658 : present? False
# el 9111 : present? True
# el 6344 : present? False
# el 2653 : present? False
# el 9805 : present? False
# el 1046 : present? True
# el 537 : present? False
# el 8203 : present? False
# el 5238 : present? False
# el 4539 : present? False
# el 9254 : present? False
# el 4330 : present? False
# el 2790 : present? False
# el 474 : present? False
# el 3911 : present? False
# el 8635 : present? False
# el 5085 : present? False
# el 7790 : present? False
# el 1007 : present? False
# el 1826 : present? False
# el 60 : present? False
# el 8078 : present? False
# el 4361 : present? True
# el 7333 : present? False
# el 4296 : present? False
# el 1339 : present? False
# el 4176 : present? False
# el 6124 : present? False
# el 7176 : present? True
# el 8245 : present? False
# el 1388 : present? False
# el 1795 : present? False
# el 9147 : present? False
# el 3627 : present? False
# el 1360 : present? False
# el 7773 : present? True
# el 4631 : present? False
# el 662 : present? False
# el 4741 : present? False
# el 5522 : present? False
# el 393 : present? False
# el 8304 : present? False
# el 9996 : present? False
# el 487 : present? False
# el 2126 : present? False
# el 6360 : present? False
# el 9792 : present? False
# el 4413 : present? False
# el 4034 : present? False
# el 8220 : present? False
# el 8077 : present? False
# el 7649 : present? False
# el 6444 : present? False
# el 548 : present? False
# el 6083 : present? False
# el 3035 : present? False
# el 1879 : present? False
# el 5057 : present? False
# el 1648 : present? False
# el 1223 : present? True
# el 6072 : present? False
# el 3595 : present? False
# el 6642 : present? False
# el 2513 : present? False
# el 7492 : present? False
# el 4274 : present? False
# el 4702 : present? False
# el 4112 : present? False
# el 6727 : present? False
# el 8985 : present? False
# el 956 : present? False
# el 6803 : present? False
# el 8030 : present? False
# el 5107 : present? False
# el 4228 : present? False
# el 4204 : present? False
# el 4241 : present? False
# el 9216 : present? False
# el 9625 : present? False
# el 4376 : present? False
# el 3119 : present? False
# el 7088 : present? False
# el 3824 : present? False
# el 8019 : present? False
# el 6994 : present? False
# el 4644 : present? False
# el 6091 : present? False
# el 6233 : present? False
# el 4752 : present? False
# el 7907 : present? False
# el 9918 : present? False
# el 2133 : present? False
# el 3131 : present? True
# el 7635 : present? False
# el 1633 : present? False
# el 4162 : present? False
# el 5 : present? False
# el 8646 : present? False
# el 2200 : present? False
# el 9444 : present? True
# el 809 : present? False
# el 1964 : present? False
# el 9989 : present? False
# el 8890 : present? False
# el 4874 : present? False
# el 2898 : present? False
# el 8646 : present? False
# el 8424 : present? False
# el 3834 : present? False
# el 395 : present? False
# el 6556 : present? False
# el 5474 : present? False
# el 2407 : present? False
# el 8311 : present? False
# el 2926 : present? False
# el 5405 : present? False
# el 3914 : present? False
# el 6457 : present? False
# el 537 : present? False
# el 2457 : present? True
# el 3489 : present? False
# el 9365 : present? False
# el 3692 : present? False
# el 6327 : present? False
# el 9269 : present? False
# el 152 : present? False
# el 7444 : present? False
# el 8401 : present? False
# el 1216 : present? False
# el 9922 : present? False
# el 2885 : present? False
# el 5341 : present? False
# el 9419 : present? False
# el 2863 : present? True
# el 9584 : present? False
# el 1999 : present? False
# el 8889 : present? False
# el 5139 : present? False
# el 1875 : present? True
# el 8006 : present? False
# el 447 : present? False
# el 2606 : present? False
# el 1879 : present? False
# el 1407 : present? False
# el 1042 : present? False
# el 8173 : present? False
# el 169 : present? False
# el 3095 : present? False
# el 6365 : present? False
# el 2709 : present? True
# el 827 : present? False
# el 4205 : present? False
# el 256 : present? False
# el 8041 : present? False
# el 7311 : present? False
# el 4139 : present? False
# el 2970 : present? False
# el 7380 : present? False
# el 3465 : present? False
# el 7171 : present? False
# el 961 : present? False
# el 2223 : present? False
# el 4654 : present? False
# el 7881 : present? False
# el 8327 : present? False
# el 6593 : present? False
# el 754 : present? False
# el 1070 : present? False
# el 5389 : present? False
# el 3254 : present? False
# el 8269 : present? False
# el 4140 : present? False
# el 2251 : present? False
# el 5380 : present? False
# el 4552 : present? False
# el 6687 : present? False
# el 1173 : present? False
# el 7578 : present? False
# el 1797 : present? True
# el 2111 : present? False
# el 9087 : present? False
# el 2324 : present? False
# el 8986 : present? False
# el 7617 : present? False
# el 2407 : present? False
# el 1624 : present? False
# el 5175 : present? False
# el 297 : present? True
# el 5207 : present? False
# el 2504 : present? False
# el 6746 : present? False
# el 6018 : present? False
# el 1353 : present? True
# el 9408 : present? False
# el 3624 : present? False
# el 6242 : present? True
# el 8298 : present? False
# el 1026 : present? False
# el 5219 : present? False
# el 3917 : present? False
# el 4585 : present? False
# el 617 : present? False
# el 4680 : present? False
# el 7766 : present? False
# el 4120 : present? False
# el 2996 : present? False
# el 1773 : present? False
# el 8009 : present? False
# el 8574 : present? False
# el 5200 : present? False
# el 5672 : present? False
# el 1569 : present? False
# el 649 : present? True
# el 9051 : present? False
# el 6815 : present? False
# el 3727 : present? False
# el 7179 : present? False
# el 2772 : present? False
# el 7629 : present? False
# el 8680 : present? False
# el 127 : present? False
# el 6684 : present? False
# el 4712 : present? False
# el 9671 : present? False
# el 7957 : present? False
# el 4367 : present? False
# el 9487 : present? False
# el 8735 : present? False
# el 3123 : present? False
# el 1799 : present? False
# el 7344 : present? False
# el 6244 : present? False
# el 1999 : present? False
# el 2602 : present? False
# el 9124 : present? False
# el 4161 : present? False
# el 2612 : present? False
# el 2551 : present? False
# el 80 : present? False
# el 4221 : present? False
# el 8930 : present? False
# el 8958 : present? False
# el 2561 : present? False
# el 9485 : present? False
# el 144 : present? False
# el 1674 : present? False
# el 1398 : present? False
# el 321 : present? False
# el 3116 : present? False
# el 339 : present? False
# el 7019 : present? False
# el 8418 : present? False
# el 9616 : present? True
# el 1638 : present? False
# el 1607 : present? False
# el 6172 : present? False
# el 1001 : present? False
# el 2575 : present? False
# el 8493 : present? False
# el 9272 : present? False
# el 7109 : present? False
# el 2727 : present? False
# el 5673 : present? False
# el 5170 : present? False
# el 4123 : present? False
# el 5665 : present? False
# el 8606 : present? True
# el 3031 : present? False
# el 7185 : present? False
# el 5575 : present? False
# el 6124 : present? False
# el 8773 : present? False
# el 8556 : present? False
# el 1360 : present? False
# el 2079 : present? False
# el 5976 : present? False
# el 8382 : present? False
# el 8336 : present? False
# el 6054 : present? False
# el 7131 : present? False
# el 8420 : present? False
# el 3288 : present? False
# el 5457 : present? False
# el 177 : present? False
# el 1476 : present? False
# el 3896 : present? False
# el 321 : present? False
# el 9294 : present? False
# el 4315 : present? False
# el 3041 : present? False
# el 694 : present? False
# el 8415 : present? False
# el 7343 : present? False
# el 8554 : present? False
# el 6087 : present? False
# el 201 : present? False
# el 572 : present? True
# el 2403 : present? False
# el 2392 : present? False
# el 742 : present? False
# el 1372 : present? False
# el 4501 : present? False
# el 8146 : present? False
# el 7847 : present? False
# el 3850 : present? False
# el 6266 : present? False
# el 8939 : present? False
# el 9676 : present? False
# el 754 : present? False
# el 2044 : present? False
# el 4661 : present? False
# el 9286 : present? False
# el 7601 : present? True
# el 8741 : present? False
# el 5947 : present? False
# el 2359 : present? False
# el 3238 : present? False
# el 9523 : present? False
# el 9147 : present? False
# el 3556 : present? False
# el 6386 : present? False
# el 9336 : present? False
# el 9655 : present? False
# el 7852 : present? True
# el 916 : present? False
# el 5855 : present? False
# el 6750 : present? False
# el 3467 : present? False
# el 5087 : present? True
# el 4928 : present? False
# el 5635 : present? False
# el 3036 : present? False
# el 9763 : present? False
# el 5638 : present? False
# el 8916 : present? False
# el 893 : present? False
# el 9929 : present? False
# el 1031 : present? False
# el 5612 : present? False
# el 5689 : present? False
# el 4483 : present? False
# el 1178 : present? False
# el 9023 : present? False
# el 1967 : present? False
# el 3634 : present? False
# el 2611 : present? False
# el 3713 : present? False
# el 5464 : present? True
# el 7304 : present? False
# el 4621 : present? False
# el 2214 : present? False
# el 1544 : present? False
# el 4987 : present? False
# el 57 : present? False
# el 4176 : present? False
# el 2114 : present? False
# el 5657 : present? False
# el 4480 : present? False
# el 3680 : present? False
# el 3764 : present? True
# el 7779 : present? False
# el 6440 : present? False
# el 1040 : present? False
# el 2261 : present? False
# el 5834 : present? False
# el 6036 : present? True
# el 4914 : present? False
# el 9782 : present? False
# el 3766 : present? False
# el 2747 : present? False
# el 6277 : present? False
# el 102 : present? False
# el 1232 : present? False
# el 3186 : present? False
# el 5809 : present? False
# el 5502 : present? False
# el 9449 : present? False
# el 6173 : present? False
# el 6510 : present? False
# el 6313 : present? False
# el 4652 : present? False
# el 3370 : present? False
# el 753 : present? False
# el 9579 : present? False
# el 7319 : present? True
# el 7113 : present? False
# el 4631 : present? False
# el 1451 : present? False
# el 5483 : present? False
# el 7789 : present? False
# el 7570 : present? False
# el 45 : present? False
# el 4202 : present? False
# el 784 : present? False
# el 6621 : present? False
# el 587 : present? False
# el 1143 : present? False
# el 5917 : present? False
# el 6001 : present? False
# el 7545 : present? False
# el 1628 : present? False
# el 2451 : present? False
# el 4222 : present? False
# el 5545 : present? False
# el 8443 : present? False
# el 9527 : present? False
# el 3245 : present? False
# el 4659 : present? True
# el 728 : present? True
# el 5632 : present? False
# el 7556 : present? False
# el 7526 : present? False
# el 5906 : present? False
# el 4061 : present? False
# el 5978 : present? False
# el 1386 : present? False
# el 7612 : present? False
# el 9455 : present? False
# el 4916 : present? False
# el 7749 : present? False
# el 8718 : present? False
# el 5669 : present? False
# el 7518 : present? False
# el 6175 : present? False
# el 4582 : present? False
# el 292 : present? False
# el 9221 : present? False
# el 7178 : present? False
# el 7902 : present? False
# el 5703 : present? False
# el 9565 : present? False
# el 2897 : present? False
# el 507 : present? False
# el 94 : present? False
# el 766 : present? False
# el 4643 : present? False
# el 6896 : present? False
# el 5783 : present? False
# el 5238 : present? False
# el 9773 : present? False
# el 5706 : present? False
# el 2452 : present? False
# el 3886 : present? False
# el 1824 : present? False
# el 3642 : present? False
# el 4469 : present? True
# el 5449 : present? False
# el 2543 : present? False
# el 4464 : present? False
# el 830 : present? False
# el 3444 : present? False
# el 8104 : present? False
# el 8885 : present? False
# el 1732 : present? False
# el 9146 : present? False
# el 5054 : present? False
# el 199 : present? False
# el 6436 : present? False
# el 776 : present? False
# el 5627 : present? False
# el 6929 : present? False
# el 9548 : present? False
# el 2260 : present? False
# el 5115 : present? True
# el 8011 : present? False
# el 7194 : present? False
# el 6668 : present? False
# el 6003 : present? False
# el 3805 : present? False
# el 365 : present? False
# el 5807 : present? True
# el 9023 : present? False
# el 9999 : present? False
# el 3862 : present? False
# el 7166 : present? False
# el 7001 : present? False
# el 8055 : present? False
# el 3494 : present? True
# el 1175 : present? True
# el 4945 : present? False
# el 7680 : present? False
# el 4465 : present? False
# el 9152 : present? True
# el 8995 : present? False
# el 744 : present? False
# el 1384 : present? False
# el 3716 : present? False
# el 8039 : present? False
# el 3935 : present? False
# el 7103 : present? False
# el 4821 : present? False
# el 1848 : present? False
# el 4862 : present? False
# el 9529 : present? True
# el 6752 : present? False
# el 7167 : present? False
# el 6075 : present? False
# el 1572 : present? False
# el 453 : present? False
# el 8081 : present? False
# el 5864 : present? False
# el 2924 : present? True
# el 8651 : present? False
# el 2141 : present? False
# el 9136 : present? True
# el 1599 : present? False
# el 8980 : present? False
# el 3521 : present? False
# el 7241 : present? False
# el 52 : present? False
# el 3999 : present? True
# el 4082 : present? False
# el 3085 : present? False
# el 1294 : present? False
# el 2608 : present? True
# el 3409 : present? False
# el 9602 : present? False
# el 2453 : present? False
# el 3774 : present? False
# el 2818 : present? False
# el 5508 : present? False
# el 5231 : present? False
# el 8453 : present? False
# el 8858 : present? False
# el 5065 : present? False
# el 2710 : present? False
# el 3057 : present? False
# el 1913 : present? False
# el 5521 : present? False
# el 9753 : present? False
# el 4627 : present? False
# el 6912 : present? False
# el 8584 : present? False
# el 6662 : present? False
# el 7386 : present? False
# el 41 : present? False
# el 1507 : present? False
# el 2250 : present? False
# el 4413 : present? False
# el 5943 : present? False
# el 6602 : present? False
# el 6549 : present? False
# el 9060 : present? False
# el 9794 : present? False
# el 8148 : present? False
# el 7695 : present? False
# el 6421 : present? True
# el 1963 : present? False
# el 7025 : present? True
# el 8867 : present? True
# el 5295 : present? False
# el 5156 : present? False
# el 710 : present? False
# el 9472 : present? False
# el 4476 : present? False
# el 7257 : present? False
# el 6588 : present? False
# el 6601 : present? True
# el 8543 : present? False
# el 6399 : present? False
# el 2226 : present? False
# el 8917 : present? False
# el 3248 : present? True
# el 5360 : present? False
# el 8926 : present? False
# el 9235 : present? False
# el 7744 : present? True
# el 3287 : present? False
# el 8208 : present? False
# el 8340 : present? False
# el 1623 : present? False
# el 5424 : present? False
# el 4182 : present? False
# el 5086 : present? False
# el 5097 : present? False
# el 3115 : present? False
# el 6590 : present? False
# el 1978 : present? False
# el 5378 : present? True
# el 802 : present? False
# el 2902 : present? False
# el 1187 : present? True
# el 6320 : present? False
# el 5455 : present? True
# el 991 : present? False
# el 7829 : present? False
# el 5152 : present? False
# el 1739 : present? True
# el 1259 : present? False
# el 3560 : present? True
# el 5971 : present? False
# el 8047 : present? False
# el 1305 : present? False
# el 5424 : present? False
# el 4585 : present? False
# el 1424 : present? False
# el 9052 : present? False
# el 3006 : present? False
# el 9699 : present? False
# el 3820 : present? False
# el 1869 : present? False
# el 9413 : present? True
# el 4910 : present? False
# el 7126 : present? False
# el 6422 : present? False
# el 7678 : present? True
# el 6120 : present? False
# el 5277 : present? False
# el 7665 : present? False
# el 1943 : present? False
# el 958 : present? False
# el 8765 : present? False
# el 7662 : present? False
# el 2595 : present? True
# el 3508 : present? False
# el 2322 : present? False
# el 4123 : present? False
# el 4441 : present? True
# el 798 : present? False
# el 1355 : present? False
# el 4117 : present? False
# el 988 : present? False
# el 4935 : present? False
# el 8970 : present? False
# el 9549 : present? False
# el 4480 : present? False
# el 8126 : present? False
# el 8490 : present? False
# el 2866 : present? True
# el 147 : present? False
# el 5118 : present? False
# el 8038 : present? False
# el 3742 : present? False
# el 9657 : present? False
# el 7941 : present? False
# el 1175 : present? True
# el 5455 : present? True
# el 3284 : present? False
# el 5693 : present? False
# el 49 : present? True
# el 2452 : present? False
# el 611 : present? False
# el 7000 : present? False
# el 9640 : present? False
# el 6089 : present? False
# el 1360 : present? False
# el 5827 : present? False
# el 2016 : present? False
# el 4876 : present? False
# el 7882 : present? False
# el 8748 : present? False
# el 35 : present? False
# el 289 : present? True
# el 9703 : present? False
# el 3359 : present? False
# el 2566 : present? False
# el 4583 : present? False
# el 6756 : present? False
# el 9297 : present? False
# el 2648 : present? False
# el 2763 : present? False
# el 1340 : present? False
# el 9637 : present? False
# el 7799 : present? False
# el 7312 : present? False
# el 9849 : present? False
# el 2991 : present? False
# el 472 : present? False
# el 8534 : present? False
# el 5094 : present? False
# el 9728 : present? False
# el 849 : present? False
# el 3936 : present? False
# el 6541 : present? False
# el 5982 : present? False
# el 5326 : present? False
# el 3387 : present? False
# el 2235 : present? False
# el 8764 : present? False
# el 6939 : present? True
# el 5135 : present? False
# el 6478 : present? False
# el 5614 : present? False
# el 6529 : present? False
# el 9458 : present? False
# el 5411 : present? False
# el 6652 : present? False
# el 6032 : present? False
# el 3172 : present? False
# el 8175 : present? True
# el 4872 : present? False
# el 3382 : present? False
# el 9328 : present? False
# el 9317 : present? False
# el 3006 : present? False
# el 15 : present? False
# el 9694 : present? False
# el 6816 : present? False
# el 4702 : present? False
# el 2103 : present? True
# el 9665 : present? False
# el 9770 : present? False
# el 1310 : present? False
# el 9554 : present? True
# el 9051 : present? False
# el 8643 : present? False
# el 3240 : present? False
# el 6366 : present? True
# el 5100 : present? False
# el 8736 : present? False
# el 1935 : present? False
# el 3812 : present? False
# el 4061 : present? False
# el 4237 : present? False
# el 3973 : present? False
# el 483 : present? False
# el 9226 : present? False
# el 1133 : present? False
# el 1167 : present? False
# el 228 : present? False
# el 8934 : present? False
# el 3087 : present? False
# el 3487 : present? False
# el 2320 : present? False
# el 1700 : present? False
# el 7707 : present? False
# el 5568 : present? False
# el 4519 : present? True
# el 1214 : present? False
# el 7034 : present? False
# el 4082 : present? False
#
# In order DFS (first 100 elements):
# [9, 12, 17, 22, 34, 47, 49, 50, 64, 65, 76, 77, 87, 168, 192, 200, 212, 217, 221, 234, 271, 285, 289, 297, 305, 322, 328, 335, 338, 343, 370, 386, 390, 391, 424, 431, 464, 465, 479, 490, 503, 513, 518, 525, 534, 541, 552, 572, 599, 600, 649, 669, 675, 676, 682, 683, 690, 704, 719, 728, 783, 790, 797, 806, 823, 850, 889, 899, 925, 931, 935, 948, 965, 968, 971, 993, 1044, 1046, 1064, 1080, 1091, 1093, 1121, 1149, 1165, 1171, 1175, 1187, 1194, 1201, 1223, 1231, 1233, 1234, 1239, 1242, 1253, 1272, 1283, 1311]

# %% [markdown]
# </div>

# %% [markdown]
# 5. Implement the Generic Tree above without looking at the code.
#
# As a reminder, the connections of pointers are:
#
# ![](img/pract17/genericTreePointers.png)
#
# the ADT:
#
# ![](img/pract17/genericTreeADT.png)
#
# <div class="tggle" onclick="toggleVisibility('ex5');">Show/Hide Solution</div>
# <div id="ex5" style="display:none;">

# %% [markdown]
# check the code above.

# %% [markdown]
# </div>
